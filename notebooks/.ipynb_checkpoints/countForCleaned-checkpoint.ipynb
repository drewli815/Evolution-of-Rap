# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from string import punctuation
import re
from nltk.stem import SnowballStemmer
from autocorrect import Speller
from collections import Counter 
import timeit
from ast import literal_eval

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jialinshan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df = pd.read_csv('../data/cleaned3000.csv',converters={'After_Clean': eval})
lyricsSeries = df['After_Clean']
print(type(lyricsSeries), lyricsSeries)
c = Counter()
# for i, lyric in enumerate(lyricsSeries):
#     if i < 20:
#         print(lyric)
    # for j, word in enumerate(lyric):
    #     if i < 20 and j < 20:
    #         print(word)
        
c
# lyricsSeries
# pd.DataFrame(list(result.items()),columns = ['words','counts']).to_csv('count2010.csv')
# Out:
# <class 'pandas.core.series.Series'> 0       [letran, de, post, malone, enemy, ft, dababy, ...
# 1       [intro, cook, shit, quay, chorus, della, beery...
# 2       [intro, let, us, go, yes, yes, neko, make, mot...
# 3       [verse, yes, grow, know, wan, na, take, seat, ...
# 4       [intro, hollywood, bleed, vampire, feed, darkn...
#                               ...
# 3478    [verse, think, great, take, love, back, run, u...
# 3479                                       [instrumental]
# 3480    [intro, buy, droptop, porsche, cut, top, trap,...
# 3481    [intro, lil, boogie, bad, jazz, yung, joe, get...
# 3482    [intro, know, baby, tonight, night, tonight, n...
# Name: After_Clean, Length: 3483, dtype: object
# Counter()

# %%
word_count=df.After_Clean.apply(Counter).sum()
result = {}
for w in sorted(word_count, key=word_count.get, reverse=True):
        result[w] = word_count[w]
result
# Out:
# {'get': 33456,
#  'like': 19635,
#  'yes': 16416,
#  'know': 15617,
#  'go': 14347,
#  'say': 10740,
#  'love': 9566,
#  'na': 9428,
#  'make': 9173,
#  'oh': 8283,
#  'baby': 8261,
#  'see': 8190,
#  'let': 8088,
#  'come': 8053,
#  'verse': 8037,
#  'girl': 7422,
#  'chorus': 7345,
#  'one': 7138,
#  'back': 7119,
#  'take': 6852,
#  'tell': 6731,
#  'want': 6725,
#  'nigra': 6516,
#  'fuck': 6178,
#  'wan': 6079,
#  'gon': 5790,
#  'time': 5627,
#  'shit': 5317,
#  'look': 5295,
#  'man': 5295,
#  'much': 5281,
#  'feel': 5170,
#  'bitch': 5137,
#  'right': 5033,
#  'never': 5005,
#  'think': 4872,
#  'us': 4831,
#  'way': 4681,
#  'give': 4654,
#  'good': 4600,
#  'niggas': 4505,
#  'need': 4243,
#  '-PRON-': 4175,
#  'keep': 4132,
#  'money': 3959,
#  'boy': 3792,
#  'put': 3627,
#  'call': 3548,
#  'life': 3399,
#  'hey': 3372,
#  '—': 3370,
#  'thing': 3350,
#  'ta': 3325,
#  'day': 3283,
#  'leave': 3231,
#  'big': 3167,
#  'well': 3125,
#  'ooh': 3010,
#  'try': 2928,
#  'cause': 2865,
#  'live': 2807,
#  'uh': 2793,
#  'run': 2792,
#  'night': 2745,
#  'still': 2706,
#  'real': 2685,
#  'play': 2679,
#  'would': 2638,
#  'hit': 2633,
#  'lil': 2531,
#  'yo': 2504,
#  'new': 2501,
#  'talk': 2494,
#  'hook': 2488,
#  'even': 2469,
#  'around': 2469,
#  'home': 2442,
#  'break': 2441,
#  'stop': 2437,
#  'little': 2436,
#  'nothing': 2426,
#  'ass': 2344,
#  'turn': 2331,
#  'show': 2295,
#  'bad': 2278,
#  'hear': 2268,
#  'head': 2246,
#  'hand': 2210,
#  'every': 2179,
#  'la': 2169,
#  'rock': 2167,
#  'ride': 2098,
#  'intro': 2095,
#  'really': 2083,
#  'two': 2079,
#  'walk': 2039,
#  'world': 2037,
#  'work': 2032,
#  'ama': 2030,
#  'pop': 1993,
#  'doe': 1991,
#  'hold': 1970,
#  'light': 1968,
#  'bout': 1966,
#  'de': 1917,
#  'mind': 1886,
#  'something': 1877,
#  'move': 1851,
#  'ever': 1851,
#  'pitch': 1841,
#  'bring': 1833,
#  'long': 1826,
#  'name': 1820,
#  'hard': 1797,
#  'away': 1792,
#  'beat': 1791,
#  'high': 1783,
#  'may': 1778,
#  'watch': 1778,
#  'lie': 1776,
#  'body': 1774,
#  'god': 1769,
#  'roll': 1746,
#  'eye': 1739,
#  'young': 1696,
#  'stay': 1673,
#  'drop': 1667,
#  'start': 1656,
#  'hot': 1632,
#  'mean': 1630,
#  'fall': 1623,
#  'face': 1611,
#  'find': 1610,
#  'check': 1593,
#  'wait': 1589,
#  'black': 1584,
#  'dance': 1577,
#  'top': 1566,
#  'ah': 1540,
#  'friend': 1525,
#  'game': 1524,
#  'always': 1520,
#  'pull': 1515,
#  'everything': 1512,
#  'die': 1508,
#  'heart': 1508,
#  'throw': 1501,
#  'party': 1501,
#  'drink': 1474,
#  'bridge': 1459,
#  'use': 1451,
#  'people': 1448,
#  'outro': 1438,
#  'smoke': 1409,
#  'lose': 1405,
#  'damn': 1400,
#  'club': 1392,
#  'woo': 1385,
#  'shake': 1368,
#  'rap': 1363,
#  'da': 1361,
#  'another': 1351,
#  'street': 1351,
#  'change': 1350,
#  '\ufeff1': 1326,
#  'til': 1321,
#  'kill': 1320,
#  'fly': 1304,
#  'low': 1302,
#  'shoot': 1283,
#  'old': 1270,
#  'ask': 1260,
#  'sit': 1253,
#  'song': 1239,
#  'everybody': 1236,
#  'tonight': 1226,
#  'woman': 1226,
#  'house': 1224,
#  'stand': 1216,
#  'catch': 1211,
#  'huh': 1196,
#  'last': 1195,
#  'side': 1194,
#  'car': 1183,
#  'blow': 1156,
#  'crazy': 1153,
#  'tryna': 1140,
#  'kid': 1134,
#  'prechorus': 1127,
#  'wrong': 1126,
#  'wit': 1125,
#  'ice': 1122,
#  'jump': 1122,
#  'whole': 1121,
#  'miss': 1116,
#  'ho': 1106,
#  'buy': 1105,
#  'door': 1103,
#  'word': 1103,
#  'okay': 1090,
#  'please': 1087,
#  'nobody': 1081,
#  'pay': 1074,
#  'year': 1066,
#  'lady': 1060,
#  'lot': 1053,
#  'white': 1052,
#  'three': 1045,
#  'ready': 1040,
#  'cry': 1038,
#  'mine': 1037,
#  'round': 1030,
#  'step': 1018,
#  'bag': 1015,
#  'gang': 1007,
#  'kiss': 1006,
#  'close': 1004,
#  'end': 1004,
#  'though': 994,
#  'place': 986,
#  'mama': 975,
#  'rich': 974,
#  'stick': 954,
#  'mr': 954,
#  'touch': 953,
#  'hate': 947,
#  'meet': 946,
#  'dream': 942,
#  'believe': 942,
#  'pussy': 941,
#  'city': 940,
#  'late': 939,
#  'enough': 935,
#  'floor': 924,
#  'g': 912,
#  'block': 912,
#  'room': 912,
#  'straight': 911,
#  'many': 910,
#  'without': 910,
#  'alone': 905,
#  'hope': 905,
#  'wah': 900,
#  'next': 895,
#  'pass': 894,
#  'wish': 886,
#  'ha': 884,
#  'chain': 883,
#  'talkin': 881,
#  'care': 878,
#  'hell': 874,
#  'brown': 873,
#  'bed': 873,
#  'sleep': 872,
#  'hood': 868,
#  'j': 867,
#  'sound': 862,
#  'line': 857,
#  'eat': 855,
#  'cut': 847,
#  'cool': 846,
#  'push': 841,
#  'suck': 841,
#  'feature': 839,
#  'act': 838,
#  'short': 838,
#  'fire': 832,
#  'cold': 828,
#  'west': 817,
#  'que': 816,
#  'shawty': 813,
#  'front': 811,
#  'bust': 810,
#  'diamond': 807,
#  'four': 804,
#  'listen': 804,
#  'help': 803,
#  'mad': 803,
#  'daddy': 802,
#  'slow': 797,
#  'gun': 794,
#  'open': 790,
#  'king': 786,
#  'alright': 780,
#  'wake': 780,
#  'set': 776,
#  'spend': 775,
#  'bite': 771,
#  'inside': 768,
#  'trip': 766,
#  'cash': 762,
#  'understand': 762,
#  'brother': 761,
#  'x': 761,
#  'freak': 760,
#  'kick': 754,
#  'anything': 753,
#  'michael': 751,
#  'red': 749,
#  'send': 748,
#  'ring': 748,
#  'true': 746,
#  'morning': 745,
#  'fresh': 745,
#  'jam': 745,
#  'dick': 743,
#  'knock': 742,
#  'music': 733,
#  '‘': 730,
#  'somebody': 728,
#  'maybe': 727,
#  'drake': 727,
#  'drive': 726,
#  'remember': 725,
#  'dog': 718,
#  'fight': 718,
#  'hundred': 716,
#  'wonder': 713,
#  'chill': 707,
#  'cup': 694,
#  'phone': 691,
#  'star': 689,
#  'air': 688,
#  'child': 685,
#  'whip': 684,
#  'soul': 684,
#  'pick': 682,
#  'sure': 680,
#  'fast': 674,
#  'grind': 672,
#  'hurt': 671,
#  'full': 671,
#  'b': 670,
#  'free': 667,
#  'main': 666,
#  'guess': 665,
#  'ball': 660,
#  'matt': 658,
#  'since': 658,
#  'win': 658,
#  'deep': 654,
#  'pain': 642,
#  'minute': 639,
#  'must': 636,
#  'dollar': 635,
#  'save': 635,
#  'fine': 631,
#  'grow': 630,
#  'forget': 629,
#  'else': 627,
#  'together': 627,
#  'mother': 627,
#  'school': 625,
#  'great': 625,
#  'count': 622,
#  'nah': 622,
#  'happen': 621,
#  'wayne': 621,
#  'wild': 619,
#  'wall': 618,
#  'mam': 617,
#  'chris': 612,
#  'type': 610,
#  'rhyme': 609,
#  'mouth': 608,
#  'water': 607,
#  'father': 603,
#  'band': 602,
#  'thug': 602,
#  'burn': 601,
#  'rain': 600,
#  'tear': 599,
#  'sell': 599,
#  'c': 597,
#  'smile': 592,
#  'dead': 591,
#  'bounce': 591,
#  'chick': 590,
#  'bang': 589,
#  'boom': 589,
#  'trap': 585,
#  'sweet': 584,
#  'son': 582,
#  'sky': 582,
#  'forever': 582,
#  'write': 581,
#  'shine': 581,
#  'flow': 579,
#  'dope': 578,
#  'lord': 578,
#  'far': 577,
#  'foot': 573,
#  'wear': 573,
#  'dad': 573,
#  'switch': 571,
#  'future': 571,
#  'hang': 571,
#  'skirt': 571,
#  'deal': 566,
#  'def': 564,
#  'seem': 562,
#  'road': 562,
#  'harry': 560,
#  'sing': 557,
#  'movie': 557,
#  'speak': 553,
#  'bottle': 552,
#  'hair': 551,
#  'sorry': 550,
#  'worry': 550,
#  'uhhuh': 549,
#  'guy': 548,
#  'key': 547,
#  'doi': 546,
#  'part': 546,
#  'dirty': 546,
#  'numb': 545,
#  'fat': 544,
#  'couple': 543,
#  'sex': 541,
#  'follow': 541,
#  'ft': 539,
#  'family': 536,
#  'nice': 535,
#  'hop': 533,
#  'bet': 532,
#  'million': 531,
#  'laugh': 531,
#  'five': 531,
#  'book': 530,
#  'picture': 530,
#  'till': 529,
#  'bar': 525,
#  'scream': 525,
#  'kanye': 525,
#  'pretty': 524,
#  'blue': 523,
#  'different': 523,
#  'strong': 519,
#  'dogg': 519,
#  'alma': 517,
#  'crow': 516,
#  'today': 515,
#  'blood': 515,
#  'paper': 513,
#  'mike': 513,
#  'trust': 513,
#  'lock': 510,
#  'ay': 509,
#  'problem': 508,
#  'feat': 508,
#  'en': 507,
#  'bank': 507,
#  'sign': 502,
#  'kind': 500,
#  'style': 499,
#  'gucci': 498,
#  'already': 496,
#  'dark': 495,
#  'loud': 494,
#  'wife': 493,
#  'promise': 492,
#  'swear': 490,
#  'someone': 489,
#  'ten': 488,
#  'chance': 485,
#  'wet': 484,
#  'week': 480,
#  'slide': 478,
#  'gold': 475,
#  'arm': 475,
#  'summer': 473,
#  'wrist': 470,
#  'dat': 470,
#  'babe': 469,
#  'thank': 467,
#  'read': 467,
#  'behind': 466,
#  'fact': 466,
#  'begin': 465,
#  'war': 464,
#  'bow': 463,
#  'sean': 463,
#  'whatever': 461,
#  'wee': 461,
#  'boss': 460,
#  'shot': 456,
#  'ohoh': 456,
#  'track': 453,
#  'state': 450,
#  'moment': 449,
#  'pray': 448,
#  'rest': 448,
#  'soon': 447,
#  'business': 447,
#  'card': 447,
#  'park': 446,
#  'clear': 446,
#  'con': 445,
#  'neck': 444,
#  'happy': 443,
#  'green': 443,
#  'ghetto': 440,
#  'hip': 438,
#  'truth': 436,
#  'clothe': 434,
#  'e': 434,
#  'sometimes': 433,
#  'fool': 433,
#  'twist': 433,
#  'spot': 432,
#  'pack': 431,
#  'outta': 430,
#  'easy': 429,
#  'flip': 429,
#  'booty': 429,
#  'power': 427,
#  'death': 426,
#  'control': 426,
#  'pump': 426,
#  'drug': 425,
#  'shoe': 424,
#  'town': 423,
#  'cop': 423,
#  'bottom': 421,
#  'stack': 420,
#  'fade': 420,
#  'pocket': 420,
#  'pour': 419,
#  'plan': 419,
#  'post': 416,
#  'point': 416,
#  'outside': 414,
#  'sick': 413,
#  'quick': 413,
#  'lane': 413,
#  'reason': 411,
#  'probably': 411,
#  'brain': 410,
#  'comma': 410,
#  'joe': 410,
#  'grab': 408,
#  'scare': 406,
#  'wave': 406,
#  'heaven': 405,
#  'refrain': 403,
#  'past': 403,
#  'job': 401,
#  'nicki': 401,
#  'reach': 400,
#  'treat': 400,
#  'rise': 400,
#  'clean': 400,
#  'rack': 399,
#  'case': 398,
#  'finger': 398,
#  'bear': 396,
#  'dawn': 395,
#  'build': 394,
#  'shop': 394,
#  'learn': 391,
#  'window': 390,
#  'half': 390,
#  'dress': 387,
#  'tip': 386,
#  'sun': 384,
#  'lean': 384,
#  'beautiful': 384,
#  'question': 383,
#  'clap': 382,
#  'story': 381,
#  'shut': 380,
#  'sexy': 380,
#  'jay': 380,
#  'dem': 379,
#  'ms': 378,
#  'master': 376,
#  'n': 375,
#  'remix': 375,
#  'leg': 373,
#  'justin': 371,
#  'player': 370,
#  'scott': 369,
#  'six': 368,
#  'none': 368,
#  'buck': 368,
#  'hello': 367,
#  'malachi': 366,
#  'double': 365,
#  'bill': 365,
#  'postchorus': 364,
#  'serve': 364,
#  'dr': 364,
#  'box': 363,
#  'travis': 363,
#  'hol': 363,
#  'record': 362,
#  'haha': 360,
#  'respect': 359,
#  'motherfucker': 359,
#  'mm': 356,
#  'breathe': 356,
#  'blame': 356,
#  'rule': 355,
#  'hh': 355,
#  'tire': 355,
#  'bone': 354,
#  'stuff': 353,
#  'crack': 353,
#  'un': 352,
#  '…': 352,
#  'team': 352,
#  'bread': 352,
#  'ship': 351,
#  'along': 351,
#  'eminem': 351,
#  'level': 350,
#  'rapper': 349,
#  'york': 349,
#  'tight': 348,
#  'piece': 348,
#  'middle': 348,
#  'hiphop': 348,
#  'kinda': 347,
#  'tommy': 346,
#  'fit': 344,
#  'alive': 344,
#  'lip': 343,
#  'class': 343,
#  'choose': 342,
#  'seat': 341,
#  'hour': 341,
#  'funny': 340,
#  'mo': 340,
#  'suppose': 340,
#  'boogie': 339,
#  'magic': 339,
#  'yet': 337,
#  'album': 337,
#  'taste': 336,
#  'thousand': 335,
#  'stupid': 335,
#  'plus': 334,
#  'hide': 333,
#  'fill': 332,
#  'bless': 332,
#  'hustle': 331,
#  'snoop': 330,
#  'lick': 329,
#  'latin': 328,
#  'hill': 327,
#  'holly': 327,
#  'murder': 326,
#  'fan': 325,
#  'l': 325,
#  'dig': 325,
#  'peace': 324,
#  'land': 322,
#  'single': 322,
#  'dre': 322,
#  'mill': 321,
#  'p': 321,
#  'minaj': 320,
#  'teach': 319,
#  'fake': 318,
#  'lonely': 318,
#  'raise': 317,
#  'brand': 317,
#  'swing': 316,
#  'knee': 313,
#  'note': 313,
#  'k': 312,
#  'worth': 311,
#  'lo': 310,
#  'spit': 310,
#  'link': 310,
#  'queen': 310,
#  'ey': 310,
#  'della': 308,
#  'wood': 308,
#  'funky': 308,
#  'mess': 306,
#  'carry': 305,
#  'everyone': 304,
#  'south': 304,
#  'table': 304,
#  'fear': 303,
#  'stone': 303,
#  'tha': 303,
#  'trick': 302,
#  'dumb': 301,
#  'ago': 301,
#  'sir': 300,
#  'juice': 300,
#  'funk': 300,
#  'el': 299,
#  'poor': 299,
#  'gangsta': 299,
#  'nine': 298,
#  'mai': 298,
#  'devil': 297,
#  'scene': 297,
#  'eh': 296,
#  'become': 294,
#  'et': 293,
#  'lamar': 293,
#  'benz': 291,
#  'brick': 291,
#  'beyondé': 291,
#  'fun': 290,
#  'handle': 289,
#  'thick': 289,
#  'pimp': 289,
#  'motherfuckin': 288,
#  'jeans': 288,
#  'mic': 288,
#  'super': 287,
#  'jesus': 287,
#  'trunk': 287,
#  'rush': 287,
#  'mi': 286,
#  'le': 286,
#  'special': 286,
#  'wow': 285,
#  'heat': 285,
#  'dip': 285,
#  'kitchen': 284,
#  'cap': 284,
#  'corner': 284,
#  'country': 284,
#  'sweat': 284,
#  'angel': 284,
#  'trouble': 284,
#  'crib': 283,
#  'law': 283,
#  'nasty': 283,
#  'login': 282,
#  'waste': 282,
#  'loose': 281,
#  'figure': 281,
#  'actin': 280,
#  'sugar': 280,
#  'kelly': 280,
#  'clip': 278,
#  'produce': 278,
#  'cross': 277,
#  'savage': 276,
#  'east': 275,
#  'earth': 275,
#  'lift': 275,
#  'pound': 274,
#  'chase': 273,
#  'smell': 273,
#  'interlude': 272,
#  'everywhere': 272,
#  'lead': 271,
#  'spin': 271,
#  'perfect': 271,
#  'ye': 271,
#  'singe': 270,
#  'kendrick': 270,
#  'gas': 269,
#  'cat': 269,
#  'mix': 269,
#  'ron': 269,
#  'drip': 268,
#  'flash': 268,
#  'je': 268,
#  'girlfriend': 268,
#  'ear': 267,
#  'rappers': 267,
#  'small': 267,
#  'tie': 264,
#  'doctor': 264,
#  'tooth': 263,
#  'tea': 263,
#  '2': 262,
#  'bird': 262,
#  'coast': 262,
#  'yellow': 260,
#  'force': 260,
#  'foreign': 259,
#  'date': 259,
#  'shoulder': 259,
#  'nas': 259,
#  'flo': 259,
#  'cook': 258,
#  'cream': 258,
#  'rick': 258,
#  'voice': 258,
#  'rip': 257,
#  'cover': 256,
#  'candy': 256,
#  'bomb': 255,
#  'sugarhill': 255,
#  'nose': 254,
#  'st': 254,
#  'fo': 254,
#  'month': 253,
#  'tpain': 253,
#  'lt': 253,
#  'freeze': 252,
#  'jet': 252,
#  'profile': 252,
#  'safe': 251,
#  'heavy': 251,
#  'rather': 250,
#  'putt': 250,
#  'float': 250,
#  'haters': 249,
#  'vibe': 249,
#  'slim': 249,
#  'quavo': 248,
#  'price': 248,
#  'mrs': 248,
#  'bump': 248,
#  'tool': 248,
#  'coupe': 247,
#  'finish': 246,
#  'afraid': 246,
#  'flame': 246,
#  'r': 246,
#  'tomorrow': 245,
#  'bass': 245,
#  'enjoy': 245,
#  'glass': 244,
#  'dough': 243,
#  'police': 243,
#  'sin': 242,
#  'sippin': 242,
#  'order': 242,
#  'favorite': 242,
#  'paul': 242,
#  'ich': 242,
#  'grand': 241,
#  'blunt': 241,
#  'il': 241,
#  'cake': 240,
#  'roof': 239,
#  'enemy': 238,
#  'space': 238,
#  'america': 238,
#  'press': 238,
#  'pant': 237,
#  'ballin': 237,
#  'age': 237,
#  'steal': 236,
#  'zone': 236,
#  'toe': 236,
#  'store': 236,
#  'slip': 235,
#  'fame': 235,
#  'lover': 235,
#  'feeling': 234,
#  'church': 234,
#  'tongue': 233,
#  'ti': 233,
#  'yea': 233,
#  'ghost': 232,
#  'sister': 231,
#  'soldier': 231,
#  'es': 230,
#  'dude': 230,
#  'molly': 230,
#  'weekend': 230,
#  'action': 229,
#  'across': 229,
#  'crowd': 228,
#  'deserve': 228,
#  'uncle': 228,
#  'everyday': 228,
#  'mom': 227,
#  'plug': 227,
#  'mob': 227,
#  'se': 226,
#  'stress': 225,
#  'chest': 225,
#  'bentley': 225,
#  'race': 225,
#  'mmm': 225,
#  'ahead': 225,
#  'moon': 224,
#  'answer': 224,
#  'nut': 224,
#  'nation': 224,
#  'wheel': 224,
#  'limit': 224,
#  'louis': 223,
#  'beg': 223,
#  'sonny': 223,
#  'bend': 222,
#  'video': 222,
#  'trina': 221,
#  'american': 221,
#  'base': 221,
#  'rob': 220,
#  'beef': 219,
#  'killer': 219,
#  'doubt': 219,
#  'quit': 218,
#  'boo': 218,
#  'skin': 218,
#  'khaled': 218,
#  'u': 218,
#  'puff': 218,
#  'raw': 217,
#  'des': 217,
#  'spring': 217,
#  'ill': 217,
#  'famous': 216,
#  'ross': 216,
#  'field': 215,
#  'clock': 214,
#  'mirror': 214,
#  'corleone': 214,
#  'shirt': 214,
#  'excuse': 213,
#  'goal': 213,
#  'groove': 213,
#  'welcome': 213,
#  'original': 213,
#  'radio': 212,
#  'warm': 212,
#  'cent': 212,
#  'stage': 212,
#  'mark': 212,
#  'tee': 212,
#  'bobby': 212,
#  'paint': 212,
#  'wrap': 211,
#  'grandma': 211,
#  'breath': 211,
#  'twin': 211,
#  'whatcha': 211,
#  'sense': 210,
#  'limerick': 210,
#  'tu': 209,
#  'te': 209,
#  'group': 209,
#  'speed': 209,
#  'battle': 209,
#  'insane': 208,
#  'versace': 208,
#  'finally': 207,
#  'color': 207,
#  'honey': 207,
#  'blind': 206,
#  'meek': 206,
#  'jack': 206,
#  'jayz': 206,
#  'rank': 205,
#  'truck': 205,
#  'mary': 205,
#  'bus': 204,
#  'gh': 204,
#  'smooth': 204,
#  'wide': 204,
#  'tree': 204,
#  'test': 203,
#  'creep': 203,
#  'sock': 203,
#  'cloud': 203,
#  'jazz': 203,
#  'early': 203,
#  'pac': 202,
#  'à': 202,
#  'search': 201,
#  'anymore': 201,
#  'shout': 201,
#  'mack': 201,
#  'yell': 201,
#  'cost': 200,
#  'butt': 200,
#  'squad': 200,
#  'di': 200,
#  'chop': 200,
#  'usher': 200,
#  'th': 200,
#  'empty': 199,
#  'pa': 199,
#  'stare': 199,
#  'marry': 198,
#  'lee': 198,
#  'course': 198,
#  'whoop': 198,
#  'elektra': 198,
#  'quiet': 197,
#  'sip': 197,
#  'map': 197,
#  'chicken': 197,
#  'smash': 197,
#  'repeat': 197,
#  'seven': 196,
#  'food': 196,
#  'pink': 196,
#  'judge': 195,
#  'row': 195,
#  'mall': 195,
#  'tweak': 195,
#  'horse': 195,
#  ...}
