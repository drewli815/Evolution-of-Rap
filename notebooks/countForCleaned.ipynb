# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from string import punctuation
import re
from nltk.stem import SnowballStemmer
from autocorrect import Speller
from collections import Counter 
import timeit

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ricke\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv('../data/cleaned3000.csv')
lyricsSeries = df['After_Clean'].astype(tuple)
print(type(lyricsSeries), lyricsSeries)
c = Counter()
# for i, lyric in enumerate(lyricsSeries):
#     if i < 20:
#         print(lyric)
    # for j, word in enumerate(lyric):
    #     if i < 20 and j < 20:
    #         print(word)
        
c
# lyricsSeries
# pd.DataFrame(list(result.items()),columns = ['words','counts']).to_csv('count2010.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c157a59fc277> in <module>
#       1 df = pd.read_csv('../data/cleaned3000.csv')
# ----> 2 lyricsSeries = df['After_Clean'].astype(tuple)
#       3 print(type(lyricsSeries), lyricsSeries)
#       4 c = Counter()
#       5 # for i, lyric in enumerate(lyricsSeries):
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
# ...

# %%
result = {}
for w in sorted(word_count, key=word_count.get, reverse=True):
        result[w] = word_count[w]
result
# Out:
# {"'": 2695978,
#  ' ': 1344547,
#  ',': 1344506,
#  'e': 744075,
#  'a': 507362,
#  'o': 459472,
#  't': 418328,
#  'i': 380678,
#  'r': 372650,
#  'n': 368272,
#  'l': 359477,
#  's': 324110,
#  'h': 255165,
#  'c': 220609,
#  'g': 208575,
#  'd': 196206,
#  'u': 188357,
#  'm': 179213,
#  'y': 174847,
#  'k': 168837,
#  'p': 145099,
#  'b': 139728,
#  'w': 128329,
#  'f': 93505,
#  'v': 77171,
#  'j': 17081,
#  'z': 11641,
#  'x': 11057,
#  '-': 8350,
#  'q': 6724,
#  'P': 4175,
#  'R': 4175,
#  'O': 4175,
#  'N': 4175,
#  '[': 3483,
#  ']': 3483,
#  '—': 3371,
#  'é': 2258,
#  '\\': 1433,
#  '1': 1355,
#  'ı': 1207,
#  'ü': 742,
#  '‘': 730,
#  'í': 525,
#  'ç': 466,
#  'ş': 394,
#  'о': 371,
#  '…': 352,
#  '2': 346,
#  'ğ': 342,
#  'е': 336,
#  'ə': 332,
#  'á': 331,
#  'à': 326,
#  'ö': 308,
#  'ó': 306,
#  'ی': 255,
#  'т': 239,
#  'ê': 208,
#  'а': 197,
#  '•': 193,
#  'è': 188,
#  'в': 186,
#  'ú': 185,
#  'н': 182,
#  'у': 179,
#  '0': 177,
#  'и': 171,
#  'с': 168,
# ...
